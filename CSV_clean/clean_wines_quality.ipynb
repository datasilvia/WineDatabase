# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/GemaVNZ/Proyecto-4-/refs/heads/main/CSV/wines_quality_SPA.csv'
df = pd.read_csv(url)

# %%
df
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# ...

# %%
df_filas_nulas = df[df.isna().all(axis=1)] # visualizar filas nulas

df = df.dropna(how='all')

df
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# ...

# %%
# Eliminar filas duplicadas (manteniendo solo la primera aparición)
df_sin_duplicados = df.drop_duplicates()

# Verificar el resultado
df_sin_duplicados
# Out:
#                   winery             wine  year  rating  num_reviews country  \
# 0          Teso La Monja            Tinto  2013     4.9           58  Espana
# 1                 Artadi    Vina El Pison  2018     4.9           31  Espana
# 2           Vega Sicilia            Unico  2009     4.8         1793  Espana
# 3           Vega Sicilia            Unico  1999     4.8         1705  Espana
# 4           Vega Sicilia            Unico  1996     4.8         1309  Espana
# ...                  ...              ...   ...     ...          ...     ...
# 2046         Mustiguillo  Finca Terrerazo  2017     4.2          390  Espana
# 2047         Matarromera     Gran Reserva  2011     4.2          389  Espana
# 2048            Sei Solo         Preludio  2016     4.2          388  Espana
# 2049  Vinedos de Paganos       El Puntido  2005     4.2          384  Espana
# 6100   Remirez de Ganuza     Rioja Blanco  2017     4.2          421  Espana
#
# ...

# %%
df_sin_duplicados.dtypes
# Out:
# winery          object
# wine            object
# year            object
# rating         float64
# num_reviews      int64
# country         object
# region          object
# price          float64
# type            object
# body           float64
# acidity        float64
# dtype: object

# %%
df_sin_duplicados['designation'] = df_sin_duplicados['wine'] + ' ' + df_sin_duplicados['year'].astype(str)
# Out:
# /var/folders/8k/8w_q7kd116v1zrzns3x24cv80000gn/T/ipykernel_4944/308246664.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['designation'] = df_sin_duplicados['wine'] + ' ' + df_sin_duplicados['year'].astype(str)

# %%
df_sin_duplicados
# Out:
#                   winery             wine  year  rating  num_reviews country  \
# 0          Teso La Monja            Tinto  2013     4.9           58  Espana
# 1                 Artadi    Vina El Pison  2018     4.9           31  Espana
# 2           Vega Sicilia            Unico  2009     4.8         1793  Espana
# 3           Vega Sicilia            Unico  1999     4.8         1705  Espana
# 4           Vega Sicilia            Unico  1996     4.8         1309  Espana
# ...                  ...              ...   ...     ...          ...     ...
# 2046         Mustiguillo  Finca Terrerazo  2017     4.2          390  Espana
# 2047         Matarromera     Gran Reserva  2011     4.2          389  Espana
# 2048            Sei Solo         Preludio  2016     4.2          388  Espana
# 2049  Vinedos de Paganos       El Puntido  2005     4.2          384  Espana
# 6100   Remirez de Ganuza     Rioja Blanco  2017     4.2          421  Espana
#
# ...

# %%
df_sin_duplicados['id'] = range(1, len(df_sin_duplicados) + 1)
# Out:
# /var/folders/8k/8w_q7kd116v1zrzns3x24cv80000gn/T/ipykernel_4944/3948994774.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sin_duplicados['id'] = range(1, len(df_sin_duplicados) + 1)

# %%
df_sin_duplicados.to_csv('DataFrameGrande.csv', index=False)
df_sin_duplicados
# Out:
#                   winery             wine  year  rating  num_reviews country  \
# 0          Teso La Monja            Tinto  2013     4.9           58  Espana
# 1                 Artadi    Vina El Pison  2018     4.9           31  Espana
# 2           Vega Sicilia            Unico  2009     4.8         1793  Espana
# 3           Vega Sicilia            Unico  1999     4.8         1705  Espana
# 4           Vega Sicilia            Unico  1996     4.8         1309  Espana
# ...                  ...              ...   ...     ...          ...     ...
# 2046         Mustiguillo  Finca Terrerazo  2017     4.2          390  Espana
# 2047         Matarromera     Gran Reserva  2011     4.2          389  Espana
# 2048            Sei Solo         Preludio  2016     4.2          388  Espana
# 2049  Vinedos de Paganos       El Puntido  2005     4.2          384  Espana
# 6100   Remirez de Ganuza     Rioja Blanco  2017     4.2          421  Espana
#
# ...

# %%
df_1 = df_sin_duplicados[['winery', 'wine', 'region']]

df_1
# Out:
#                   winery             wine            region
# 0          Teso La Monja            Tinto              Toro
# 1                 Artadi    Vina El Pison    Vino de Espana
# 2           Vega Sicilia            Unico  Ribera del Duero
# 3           Vega Sicilia            Unico  Ribera del Duero
# 4           Vega Sicilia            Unico  Ribera del Duero
# ...                  ...              ...               ...
# 2046         Mustiguillo  Finca Terrerazo      El Terrerazo
# 2047         Matarromera     Gran Reserva  Ribera del Duero
# 2048            Sei Solo         Preludio  Ribera del Duero
# 2049  Vinedos de Paganos       El Puntido             Rioja
# 6100   Remirez de Ganuza     Rioja Blanco             Rioja
#
# [2048 rows x 3 columns]

# %%
df_1_clean = df_1.drop_duplicates()

df_1_clean
# Out:
#                     winery                            wine              region
# 0            Teso La Monja                           Tinto                Toro
# 1                   Artadi                   Vina El Pison      Vino de Espana
# 2             Vega Sicilia                           Unico    Ribera del Duero
# 8             Vega Sicilia  Unico Reserva Especial Edicion    Ribera del Duero
# 11     Pago de Carraovejas                       El Anejon    Ribera del Duero
# ...                    ...                             ...                 ...
# 2010              Campillo              Gran Reserva Rioja               Rioja
# 2011        Ramon do Casar                      Treixadura             Ribeiro
# 2012                Lustau       Candela Cream Dulce Sweet  Jerez-Xeres-Sherry
# 2014              Binigrau                          Nounat            Mallorca
# 2020  Conreria d'Scala Dei                   Les Brugueres            Priorato
#
# [931 rows x 3 columns]

# %%
df_1_clean.to_csv('bodega-vino-DO', index=False)
